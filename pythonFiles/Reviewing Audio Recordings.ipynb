# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# For audio processing
import librosa
import librosa.display
import IPython.display as ipd

# %%
audio_to_review = [155, 234, 247, 252, 302, 316, 352, 399, 402, 455, 535, 552, 580, 589, 590]

# %%
df2 = pd.read_csv('./labels/final.csv')

# %%
number = 708

# %%
df2.shape
# Out:
# (710, 5)

# %%
number += 1
number/(df2.shape[0]-1) * 100
# Out:
# 100.0

# %%
row = df2.iloc[number]
filename = os.path.join("audioFiles", row["fileName"] + ".wav")
print("Current Number :- {}".format(number))
print(row["gender"])
print(row["fileName"] + ".wav")
print(row["devnagariSentence"])
ipd.Audio(filename, autoplay=True)
# Out:
# Current Number :- 709
# female
# e7130c32-0f10-42db-8705-e036a4dfd7b2.wav
# लगातार तीन अर्धशतक प्रहार गर्ने खेलाडीहरुको सूचीमा सनथ जयसूर्या, साहिदा साहिद अफ्रिदी, मार्टिन गुप्टिल, विराट कोहली जस्ता क्रिकेटर छन्
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# df2.drop(index=number, axis=0, inplace=True)

# %%
df2.to_csv('./labels/final.csv', index=False)
