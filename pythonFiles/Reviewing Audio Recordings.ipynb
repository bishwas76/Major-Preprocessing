# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# For audio processing
import librosa
import librosa.display
import IPython.display as ipd

# %%
audio_to_review = [155, 234, 247, 252, 302, 316, 352, 399, 402, 455, 535, 552, 580, 589, 590]

# %%
df2 = pd.read_csv('./labels/final.csv')

# %%
number = 592

# %%
df2.shape
# Out:
# (712, 5)

# %%
number += 1
number/df2.shape[0] * 100
# Out:
# 83.14606741573034

# %%
row = df2.iloc[number]
filename = os.path.join("audioFiles", row["fileName"] + ".wav")
print("Current Number :- {}".format(number))
print(row["gender"])
print(row["fileName"] + ".wav")
print(row["devnagariSentence"])
ipd.Audio(filename, autoplay=True)
# Out:
# Current Number :- 592
# male
# f8e6b54f-575a-4871-93f6-c189acdbb69a.wav
# यहि चैत्र उनन्तिस–एकत्तिस गतेसम्म सातदोबाटोस्थित बक्सिङ हलमा हुने खुला छनोट खेलमा सहभागिता जनाउनका लागि मातहतका जिल्ला बक्सिङ संघ,क्लब र विभागीय टिमलाई तयारी थाल्न संघका प्रवक्ता श्यामकाजी अवालेले जानकारी दिए
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# df2.drop(index=number, axis=0, inplace=True)

# %%
df2.to_csv('./labels/final.csv', index=False)
